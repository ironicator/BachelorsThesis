# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set_theme()
import matplotlib.pyplot as plt

import pandas as pd
df_2 = pd.read_csv('Heatmap2.csv',index_col=0,dtype={'Qubit':str})
#print(df)
df_3 = pd.read_csv('Heatmap3.csv',index_col=0,dtype={'Qubit':str})
#print(df)
df_5 = pd.read_csv('Heatmap5.csv',index_col=0,dtype={'Qubit':str})
#print(df)


cmap = sns.cm.rocket_r

uniform_data = np.random.rand(10, 12)

ax = sns.heatmap(df_2,linewidths=.5,cmap = cmap, vmin=0, vmax=0.1)
plt.savefig('heat_2.png',bbox_inches='tight',format='png', dpi=1200)
plt. clf()

ax = sns.heatmap(df_3,linewidths=.5,cmap = cmap, vmin=0, vmax=0.1)
plt.savefig('heat_3.png',bbox_inches='tight',format='png', dpi=1200)
plt. clf()

ax = sns.heatmap(df_5,linewidths=.5,cmap = cmap, vmin=0, vmax=0.1)
plt.savefig('heat_5.png',bbox_inches='tight',format='png', dpi=1200)
